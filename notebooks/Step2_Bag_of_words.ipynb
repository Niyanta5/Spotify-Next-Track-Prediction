# %%
#importing basic libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
main_path = '/content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files'
path1_10 = '/content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF1_10'
path21_30 = '/content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF21_30'
path_df_all = '/content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/Coding_file/data_sample1.csv'

# %%
#reading the files
df = pd.read_csv(path_df_all)

# %%
df.head()
# Out:
#    track_pos      track_artist_name                       track_track_uri  \
# 0          0          The Jackson 5  spotify:track:6cb0HzFQPN4BGADOmSzPCw
# 1          1  Streetlight Manifesto  spotify:track:0HBvwy7XVhrkQljkCONgsq
# 2          2        Michael Jackson  spotify:track:5ChkMS8OtdzJeqyybCc9R5
# 3          3              Green Day  spotify:track:6L89mwZXSOwYl76YXfX13s
# 4          4      The White Stripes  spotify:track:1jNOi6m3Hn8nLEeHCp5Msr
#
#                         track_artist_uri    track_track_name  \
# 0  spotify:artist:2iE18Oxc8YSumAU232n4rW                 ABC
# 1  spotify:artist:1OKOTYGoCE2buxTYMegJp7  Point/Counterpoint
# 2  spotify:artist:3fMbdgg4jU18AjLCKBhRSm         Billie Jean
# 3  spotify:artist:7oPftvlwr6VrsViSDV7fJY         Basket Case
# 4  spotify:artist:4F84IBURUo98rz4r61KF70   Seven Nation Army
#
#                         track_album_uri  track_duration_ms  \
# 0  spotify:album:4GuzZh2dtsOjG3sMkx52eR             174866
# ...

# %% [markdown]
# #### There are 48 csv files which has to be combined as one dataframe for further processing.

# %% [markdown]
# # From df1 to 11

# %%
d1 = {}
for i in range(1,11):
  d1[f'df{i}'] = pd.read_csv(f'{path1_10}/df{i}.csv')
  if i == 1:
    df_temp1 = d1[f'df{i}']
  else:
    df_temp1 = pd.concat([df_temp1, d1[f'df{i}']])
  df_temp1.drop(columns=['Unnamed: 0'], inplace=True)

  print(f'{path1_10}/df{i}.csv')
# Out:
# /content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF1_10/df1.csv
# /content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF1_10/df2.csv
# /content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF1_10/df3.csv
# /content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF1_10/df4.csv
# /content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF1_10/df5.csv
# /content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF1_10/df6.csv
# /content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF1_10/df7.csv
# /content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF1_10/df8.csv
# /content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF1_10/df9.csv
# /content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF1_10/df10.csv

# %%
df_temp1.head()
# Out:
#      track_track_name      track_artist_name  \
# 0                 ABC          The Jackson 5
# 1  Point/Counterpoint  Streetlight Manifesto
# 2         Billie Jean        Michael Jackson
# 3         Basket Case              Green Day
# 4   Seven Nation Army      The White Stripes
#
#                                               lyrics
# 0  58 ContributorsABC Lyrics[Intro: Michael Jacks...
# 1  26 ContributorsPoint/Counterpoint Lyrics[Intro...
# 2  264 ContributorsTranslationsEspañolPortuguêsHe...
# 3  128 ContributorsTranslationsFrançaisBasket Cas...
# 4  146 ContributorsTranslationsDeutschSeven Natio...

# %%
df_temp1.shape
# Out:
# (9990, 3)

# %% [markdown]
# # From 11 to 20

# %%
path11_20 = '/content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF11_20'
d1 = {}
for i in range(11,21):
  d1[f'df{i}'] = pd.read_csv(f'{path11_20}/spotify_lyrics_df{i}.csv')
  if i == 11:
    df_temp2 = d1[f'df{i}']
  else:
    df_temp2 = pd.concat([df_temp2, d1[f'df{i}']])
  print(f'{path11_20}/spotify_lyrics_{i}.csv')
# Out:
# /content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF11_20/spotify_lyrics_11.csv
# /content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF11_20/spotify_lyrics_12.csv
# /content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF11_20/spotify_lyrics_13.csv
# /content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF11_20/spotify_lyrics_14.csv
# /content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF11_20/spotify_lyrics_15.csv
# /content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF11_20/spotify_lyrics_16.csv
# /content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF11_20/spotify_lyrics_17.csv
# /content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF11_20/spotify_lyrics_18.csv
# /content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF11_20/spotify_lyrics_19.csv
# ...

# %%
df_temp2.shape
# Out:
# (9982, 3)

# %% [markdown]
# # From 21 to 30

# %%
d1 = {}
for i in range(21,31):
  d1[f'df{i}'] = pd.read_csv(f'{path21_30}/df{i}.csv')
  if i == 21:
    df_temp3 = d1[f'df{i}']
  else:
    df_temp3 = pd.concat([df_temp3, d1[f'df{i}']])
  print(f'{path21_30}/df{i}.csv')
# Out:
# /content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF21_30/df21.csv
# /content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF21_30/df22.csv
# /content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF21_30/df23.csv
# /content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF21_30/df24.csv
# /content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF21_30/df25.csv
# /content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF21_30/df26.csv
# /content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF21_30/df27.csv
# /content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF21_30/df28.csv
# /content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF21_30/df29.csv
# /content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF21_30/df30.csv

# %%
df_temp3.head()
# Out:
#     track_track_name track_artist_name  \
# 0      Lejos De Aquí           Farruko
# 1      Noche De Sexo    Wisin & Yandel
# 2  Sigo Extrañándote          J Balvin
# 3  Bruk Off Yuh Back          Konshens
# 4       Sin Contrato            Maluma
#
#                                               lyrics
# 0  9 ContributorsLejos de Aquí Lyrics[Letra de "L...
# 1  16 ContributorsTranslationsEnglishDeutschNoche...
# 2  15 ContributorsSigo Extrañándote Lyrics[Letra ...
# 3  7 ContributorsBruk Off Yuh Back Lyrics[Intro]\...
# 4  10 ContributorsSin Contrato LyricsLetra de "Si...

# %%
df_temp3.shape
# Out:
# (9980, 3)

# %% [markdown]
# # From 41 to 48

# %%
path41_48 = '/content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF41_48'
d1 = {}
for i in range(41,49):
  d1[f'df{i}'] = pd.read_csv(f'{path41_48}/spotify_lyrics_df{i}.csv')
  if i == 41:
    df_temp5 = d1[f'df{i}']
  else:
    df_temp5 = pd.concat([df_temp5, d1[f'df{i}']])
  print(f'{path41_48}/spotify_lyrics_{i}.csv')
# Out:
# /content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF41_48/spotify_lyrics_41.csv
# /content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF41_48/spotify_lyrics_42.csv
# /content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF41_48/spotify_lyrics_43.csv
# /content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF41_48/spotify_lyrics_44.csv
# /content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF41_48/spotify_lyrics_45.csv
# /content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF41_48/spotify_lyrics_46.csv
# /content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF41_48/spotify_lyrics_47.csv
# /content/drive/MyDrive/Data Science/DataScienceGroup/1_Project_df_files/DF41_48/spotify_lyrics_48.csv

# %%
df_temp5.shape
# Out:
# (7984, 3)

# %%
df_temp2 = pd.concat([df_temp2, df_temp5])
df_temp2.shape
# Out:
# (17966, 3)

# %%
df_temp = pd.concat([df_temp1, df_temp3])
df_temp.shape
# Out:
# (19970, 3)

# %%
df_temp = pd.concat([df_temp, df_temp2])
df_temp.shape
# Out:
# (37936, 505)

# %% [markdown]
# #### Creating bag of words for lyrics

# %%
import pandas as pd
import string
from collections import Counter
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk

# Download stopwords if not already available
nltk.download('stopwords')
nltk.download('punkt')

# Load English stop words
stop_words = set(stopwords.words('english'))

# Define a function to preprocess the lyrics and create a bag of words
def create_bag_of_words(lyrics):
    if pd.isna(lyrics):  # Handle missing lyrics
        return None

    # Convert to lowercase
    lyrics = lyrics.lower()

    # Remove punctuation
    lyrics = lyrics.translate(str.maketrans('', '', string.punctuation))

    # Tokenize the text into words
    words = word_tokenize(lyrics)

    # Remove stop words
    filtered_words = [word for word in words if word not in stop_words and word.isalpha()]

    # Count the frequency of each word
    word_counts = Counter(filtered_words)

    # Get the 10 most common words
    most_common_words = [word for word, count in word_counts.most_common(10)]

    # Return as a space-separated string (bag of words)
    return ' '.join(most_common_words)


df_temp['bag_of_words'] = df_temp['lyrics'].apply(create_bag_of_words)

# Display the resulting DataFrame with the new 'bag_of_words' column
df_temp[['track_track_name', 'track_artist_name','lyrics', 'bag_of_words']].head()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#      track_track_name      track_artist_name  \
# 0                 ABC          The Jackson 5
# 1  Point/Counterpoint  Streetlight Manifesto
# 2         Billie Jean        Michael Jackson
# 3         Basket Case              Green Day
# 4   Seven Nation Army      The White Stripes
#
#                                               lyrics  \
# 0  58 ContributorsABC Lyrics[Intro: Michael Jacks...
# 1  26 ContributorsPoint/Counterpoint Lyrics[Intro...
# 2  264 ContributorsTranslationsEspañolPortuguêsHe...
# 3  128 ContributorsTranslationsFrançaisBasket Cas...
# 4  146 ContributorsTranslationsDeutschSeven Natio...
#
#                                         bag_of_words
# 0  jackson c easy love b baby michael sing come s...
# ...

# %% [markdown]
# #### Generating Sentiment scores

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.sentiment import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
# Sample DataFrame setup (Assuming df already exists with 'lyrics' and 'bag_of_words' columns)
# Example: df = pd.DataFrame({'lyrics': [...], 'bag_of_words': [...]})

# Initialize sentiment analyzer
sia = SentimentIntensityAnalyzer()

# Apply sentiment analysis on the 'bag_of_words' column
df_temp['sentiment_bag_of_words'] = df_temp['bag_of_words'].fillna('').apply(lambda words: sia.polarity_scores(words)['compound'])

# Initialize TF-IDF Vectorizer for bag_of_words
tfidf_vectorizer = TfidfVectorizer(max_features=500, stop_words='english')
tfidf_matrix = tfidf_vectorizer.fit_transform(df_temp['bag_of_words'].fillna(''))

# Convert to DataFrame for analysis
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=tfidf_vectorizer.get_feature_names_out())

# Combine with original DataFrame
df_temp = pd.concat([df_temp.reset_index(drop=True), tfidf_df.reset_index(drop=True)], axis=1)

# Display the updated DataFrame with sentiment and TF-IDF features
df_temp[['track_track_name','track_artist_name', 'bag_of_words', 'sentiment_bag_of_words']].head(10)
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#                        track_track_name      track_artist_name  \
# 0                                   ABC          The Jackson 5
# 1                    Point/Counterpoint  Streetlight Manifesto
# 2                           Billie Jean        Michael Jackson
# 3                           Basket Case              Green Day
# 4                     Seven Nation Army      The White Stripes
# 5                                  1985       Bowling For Soup
# 6                 Rollup - Baauer Remix          Flosstradamus
# 7                Dirt Off Your Shoulder                  JAY Z
# 8                      So Ruff, So Tuff                   Zapp
# 9  Snow (Hey Oh) - Hey Oh Album Version  Red Hot Chili Peppers
#
#                                         bag_of_words  sentiment_bag_of_words
# ...

# %%
df_temp.shape
# Out:
# (37936, 1005)

# %%
df.columns
# Out:
# Index(['track_pos', 'track_artist_name', 'track_track_uri', 'track_artist_uri',
#        'track_track_name', 'track_album_uri', 'track_duration_ms',
#        'track_album_name', 'playlist_pid', 'playlist_name',
#        'playlist_description', 'playlist_modified_at', 'playlist_num_artists',
#        'playlist_num_albums', 'playlist_num_tracks', 'playlist_num_followers',
#        'playlist_num_edits', 'playlist_duration_ms', 'playlist_collaborative'],
#       dtype='object')

# %%
df.drop(columns=['track_track_uri', 'track_artist_uri',
                 'playlist_pid','playlist_description','playlist_modified_at'], inplace=True)

# %%
df.drop('track_album_uri', axis = 1, inplace=True)

# %%
df_temp = df_temp[['track_track_name','track_artist_name', 'bag_of_words', 'sentiment_bag_of_words']]

# %%
df_merge = df.merge(df_temp, how='left', on= ['track_track_name','track_artist_name'])

# %%
df_merge.head()
# Out:
#    track_pos      track_artist_name    track_track_name  track_duration_ms  \
# 0          0          The Jackson 5                 ABC             174866
# 1          1  Streetlight Manifesto  Point/Counterpoint             327920
# 2          2        Michael Jackson         Billie Jean             293826
# 3          3              Green Day         Basket Case             181533
# 4          4      The White Stripes   Seven Nation Army             231800
#
#                    track_album_name playlist_name  playlist_num_artists  \
# 0                               ABC   party party                   116
# 1              Everything Goes Numb   party party                   116
# 2  Thriller 25 Super Deluxe Edition   party party                   116
# 3                            Dookie   party party                   116
# 4                          Elephant   party party                   116
#
#    playlist_num_albums  playlist_num_tracks  playlist_num_followers  \
# ...

# %%
df_merge.isnull().sum()
# Out:
# track_pos                     0
# track_artist_name             0
# track_track_name              0
# track_duration_ms             0
# track_album_name              0
# playlist_name                 0
# playlist_num_artists          0
# playlist_num_albums           0
# playlist_num_tracks           0
# playlist_num_followers        0
# playlist_num_edits            0
# playlist_duration_ms          0
# playlist_collaborative        0
# bag_of_words              16171
# sentiment_bag_of_words    11876
# dtype: int64

# %%
df_merge.shape
# Out:
# (100000, 15)

# %%
df_merge.dropna(inplace=True)

# %%
df_merge.isnull().sum()
# Out:
# track_pos                 0
# track_artist_name         0
# track_track_name          0
# track_duration_ms         0
# track_album_name          0
# playlist_name             0
# playlist_num_artists      0
# playlist_num_albums       0
# playlist_num_tracks       0
# playlist_num_followers    0
# playlist_num_edits        0
# playlist_duration_ms      0
# playlist_collaborative    0
# bag_of_words              0
# sentiment_bag_of_words    0
# dtype: int64
